# %% [markdown]
# ## Step 1: Imports

# %%
import sys
sys.path.append('../phraseextraction/')

import utility
import ranking
import pandas as pd
from rule import grammar
import candidate_generation
from ranking import TextRank


## Settings
pd.set_option('display.max_rows', 500)
# Out:
# /home/dsp/miniconda3/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# [nltk_data] Downloading package punkt to /home/dsp/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/dsp/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Step 2: Reading Data

# %%
with open('../dataset/AMZN_0001018724_10K_20191231_Item1_excerpt.txt') as company_description:
    description = company_description.read()
#print(description)

# %% [markdown]
# ## Step 3: Candidate Generation: Grammar Rules Based

# %%
grammar_model = candidate_generation.Grammar_Keyphrase(grammar)
key_phrases = grammar_model.get_keyphrases(description)
print(key_phrases)
# Out:
# ['herein by reference contain forward-looking', 'statements based on expectations', 'expressed in forward-looking statements', 'principal corporate offices are located', 'common stock is listed', 'similar terms include', 's most customer-centric company', 'competitor focus , passion for invention', 'customer sets , consisting', 'consumers , sellers , developers', 'services , such as advertising', 'sellers , vendors , publishers', 'sponsored ads , display', 'segments reflect the way', 'business performance and manages', 'net sales is contained', 'results of Whole Foods', 'online and physical stores', 'focus on selection , price', 'hundreds of millions of unique', 'third parties across dozens', 'websites , mobile apps', 'sell electronic devices', 'produce media content', 'customers low prices', 'delivery , easy-to-use functionality', 'includes unlimited free shipping', 'unlimited streaming of tens', 'movies and TV episodes , including', 'fulfill customer orders', 'number of ways , including', 'fulfillment and delivery networks', 'arrangements in certain countries', 'operate customer service centers', 'are supplemented by co-sourced arrangements', 'percentage of sales , per-unit', 'activity fees , interest', 'serve developers and enterprises', 'sizes , including start-ups', 'set of global compute', 'other service offerings', 'authors and independent publishers', 'authors and publishers choose', 'royalty option and make', 'own publishing arm', 'allow authors , musicians', 'filmmakers , skill and app developers', 'large variety of product types', 'array of competitors from many different', 'potential competitors include', 'omnichannel retailers , publishers , vendors', 'web search engines , comparison shopping websites , social', 'networks , web portals', 'means of discovering , using', 'acquiring goods and services', 'collaboration with other retailers', 'e-commerce services , including', 'development and hosting , omnichannel', 'supply chain management , advertising , fulfillment', 'provide fulfillment and logistics services', 'information technology services or products , including', 'on-premises or cloud-based infrastructure', 'design , manufacture , market', 'sell consumer electronics , telecommunication', 'grocery products online', 'businesses include selection', 'fast and reliable fulfillment', 'seller and enterprise services include', 'customers ’ ability', 'change business practices', 'competitors have greater', 'resources , longer histories', 'customers , greater brand recognition', 'control over inputs critical', 'terms from suppliers , adopt', 'aggressive pricing , pursue', 'restrictive distribution agreements', 'supply , direct consumers', 'potential customers with restrictive', 'devote more resources', 'technology , infrastructure , fulfillment', 'facilitates competitive entry', 'enhances the ability of new', 'development of new business models', 'business combinations or alliances that strengthen', 'trademarks , service marks , copyrights', 'patents , domain names', 'trade dress , trade secrets , proprietary', 'rely on trademark , copyright', 'patent law , trade-secret', 'confidentiality and/or license', 'employees , customers , partners', 'international domain names , trademarks', 'patent applications covering', 'business is affected by seasonality', 'higher sales volume', 'results include revenue', 'employment levels fluctuate', 'seasonal factors affecting', 'contractors and temporary personnel', 'works councils , statutory', 'employee representation obligations', 'union agreements in certain', 'Competition for qualified personnel', 'software engineers , computer scientists', 'investor relations website is', 'website , free of charge', 'corporate governance information', 'select press releases', 'Executive Officers and Directors', 'following tables set', 'certain information regarding', 'numerous financial leadership roles']

# %% [markdown]
# ## Step 4: Post Processing: Cleaning candidate phrases

# %% [markdown]
# ### Remove Punctuations and Digits

# %%
#1. Remove punnctuations in each phrase
phrases_wo_puncts = [utility.remove_punct_num(ph) for ph in key_phrases]
print(phrases_wo_puncts)
# Out:
# ['herein by reference contain forward-looking', 'statements based on expectations', 'expressed in forward-looking statements', 'principal corporate offices are located', 'common stock is listed', 'similar terms include', 's most customer-centric company', 'competitor focus passion for invention', 'customer sets consisting', 'consumers sellers developers', 'services such as advertising', 'sellers vendors publishers', 'sponsored ads display', 'segments reflect the way', 'business performance and manages', 'net sales is contained', 'results of Whole Foods', 'online and physical stores', 'focus on selection price', 'hundreds of millions of unique', 'third parties across dozens', 'websites mobile apps', 'sell electronic devices', 'produce media content', 'customers low prices', 'delivery easy-to-use functionality', 'includes unlimited free shipping', 'unlimited streaming of tens', 'movies and TV episodes including', 'fulfill customer orders', 'number of ways including', 'fulfillment and delivery networks', 'arrangements in certain countries', 'operate customer service centers', 'are supplemented by co-sourced arrangements', 'percentage of sales per-unit', 'activity fees interest', 'serve developers and enterprises', 'sizes including start-ups', 'set of global compute', 'other service offerings', 'authors and independent publishers', 'authors and publishers choose', 'royalty option and make', 'own publishing arm', 'allow authors musicians', 'filmmakers skill and app developers', 'large variety of product types', 'array of competitors from many different', 'potential competitors include', 'omnichannel retailers publishers vendors', 'web search engines comparison shopping websites social', 'networks web portals', 'means of discovering using', 'acquiring goods and services', 'collaboration with other retailers', 'e-commerce services including', 'development and hosting omnichannel', 'supply chain management advertising fulfillment', 'provide fulfillment and logistics services', 'information technology services or products including', 'on-premises or cloud-based infrastructure', 'design manufacture market', 'sell consumer electronics telecommunication', 'grocery products online', 'businesses include selection', 'fast and reliable fulfillment', 'seller and enterprise services include', 'customers ability', 'change business practices', 'competitors have greater', 'resources longer histories', 'customers greater brand recognition', 'control over inputs critical', 'terms from suppliers adopt', 'aggressive pricing pursue', 'restrictive distribution agreements', 'supply direct consumers', 'potential customers with restrictive', 'devote more resources', 'technology infrastructure fulfillment', 'facilitates competitive entry', 'enhances the ability of new', 'development of new business models', 'business combinations or alliances that strengthen', 'trademarks service marks copyrights', 'patents domain names', 'trade dress trade secrets proprietary', 'rely on trademark copyright', 'patent law trade-secret', 'confidentiality and or license', 'employees customers partners', 'international domain names trademarks', 'patent applications covering', 'business is affected by seasonality', 'higher sales volume', 'results include revenue', 'employment levels fluctuate', 'seasonal factors affecting', 'contractors and temporary personnel', 'works councils statutory', 'employee representation obligations', 'union agreements in certain', 'Competition for qualified personnel', 'software engineers computer scientists', 'investor relations website is', 'website free of charge', 'corporate governance information', 'select press releases', 'Executive Officers and Directors', 'following tables set', 'certain information regarding', 'numerous financial leadership roles']

# %% [markdown]
# ### Remove Stopwords

# %%
#2. Remove stop words from phrases

custom_stop_words = ['include','including','provide','provides','offers','related','new', 'allowed','help','overall','array','without','with','persuant',
                 'legacy','existing','exists','addition','additional','ensure','used','uses','process','offered','described','using','provided','sold',
                 'allows','providing','following','follows','rate','labels','come','vast','covers','end','late','use','allowing','exiting','full','many',
                'includes','earlier','become','upon','allow','among','required','based','higher','exciting','seen','certain','see','continue','various',
                'trademarks','patents','copyrights','intellectual','patent','trade-secret','trademark','copyright']

phrases_wo_stopwords = [utility.remove_stopwords(ph, custom_stop_words) for ph in phrases_wo_puncts]
print(phrases_wo_stopwords)
# Out:
# ['reference forward-looking', 'statements expectations', 'expressed forward-looking statements', 'principal corporate offices located', 'common stock listed', 'similar terms', 'customer-centric company', 'competitor focus passion invention', 'customer sets consisting', 'consumers sellers developers', 'services advertising', 'sellers vendors publishers', 'sponsored ads display', 'segments reflect', 'business performance manages', 'net sales contained', 'results Whole Foods', 'online physical stores', 'focus selection price', 'hundreds millions unique', 'parties dozens', 'websites mobile apps', 'sell electronic devices', 'produce media content', 'customers low prices', 'delivery easy-to-use functionality', 'unlimited free shipping', 'unlimited streaming tens', 'movies TV episodes', 'fulfill customer orders', 'number ways', 'fulfillment delivery networks', 'arrangements countries', 'operate customer service centers', 'supplemented co-sourced arrangements', 'percentage sales per-unit', 'activity fees', 'serve developers enterprises', 'sizes start-ups', 'set global compute', 'service offerings', 'authors independent publishers', 'authors publishers choose', 'royalty option', 'publishing arm', 'authors musicians', 'filmmakers skill app developers', 'large variety product types', 'competitors', 'potential competitors', 'omnichannel retailers publishers vendors', 'web search engines comparison shopping websites social', 'networks web portals', 'means discovering', 'acquiring goods services', 'collaboration retailers', 'e-commerce services', 'development hosting omnichannel', 'supply chain management advertising fulfillment', 'fulfillment logistics services', 'information technology services products', 'on-premises cloud-based infrastructure', 'design manufacture market', 'sell consumer electronics telecommunication', 'grocery products online', 'businesses selection', 'fast reliable fulfillment', 'seller enterprise services', 'customers ability', 'change business practices', 'competitors greater', 'resources longer histories', 'customers greater brand recognition', 'control inputs critical', 'terms suppliers adopt', 'aggressive pricing pursue', 'restrictive distribution agreements', 'supply direct consumers', 'potential customers restrictive', 'devote resources', 'technology infrastructure fulfillment', 'facilitates competitive entry', 'enhances ability', 'development business models', 'business combinations alliances strengthen', 'service marks', 'domain names', 'trade dress trade secrets proprietary', 'rely', 'law', 'confidentiality license', 'employees customers partners', 'international domain names', 'applications covering', 'business affected seasonality', 'sales volume', 'results revenue', 'employment levels fluctuate', 'seasonal factors affecting', 'contractors temporary personnel', 'works councils statutory', 'employee representation obligations', 'union agreements', 'Competition qualified personnel', 'software engineers scientists', 'investor relations website', 'website free charge', 'corporate governance information', 'select press releases', 'Executive Officers Directors', 'tables set', 'information', 'numerous financial leadership roles']

# %% [markdown]
# ### Remove Non english words

# %%
#3. Remove non english words in each phrase
phrases_wo_nonenglish_words = [utility.remove_non_english(phrase) for phrase in phrases_wo_stopwords]
print(phrases_wo_nonenglish_words)
# Out:
# ['reference forward-looking', 'statements expectations', 'expressed forward-looking statements', 'principal corporate offices located', 'common stock listed', 'similar terms', 'company', 'competitor focus passion invention', 'customer sets consisting', 'consumers sellers developers', 'services advertising', 'sellers vendors publishers', 'sponsored ads display', 'segments reflect', 'business performance manages', 'net sales contained', 'results Whole Foods', 'online physical stores', 'focus selection price', 'hundreds millions unique', 'parties dozens', 'websites mobile apps', 'sell electronic devices', 'produce media content', 'customers low prices', 'delivery easy-to-use functionality', 'unlimited free shipping', 'unlimited streaming tens', 'movies TV episodes', 'fulfill customer orders', 'number ways', 'fulfillment delivery networks', 'arrangements countries', 'operate customer service centers', 'supplemented co-sourced arrangements', 'percentage sales per-unit', 'activity fees', 'serve developers enterprises', 'sizes start-ups', 'set global compute', 'service offerings', 'authors independent publishers', 'authors publishers choose', 'royalty option', 'publishing arm', 'authors musicians', 'filmmakers skill app developers', 'large variety product types', 'competitors', 'potential competitors', 'retailers publishers vendors', 'web search engines comparison shopping websites social', 'networks web portals', 'means discovering', 'acquiring goods services', 'collaboration retailers', 'e-commerce services', 'development hosting', 'supply chain management advertising fulfillment', 'fulfillment logistics services', 'information technology services products', 'on-premises cloud-based infrastructure', 'design manufacture market', 'sell consumer electronics telecommunication', 'grocery products online', 'businesses selection', 'fast reliable fulfillment', 'seller enterprise services', 'customers ability', 'change business practices', 'competitors greater', 'resources longer histories', 'customers greater brand recognition', 'control inputs critical', 'terms suppliers adopt', 'aggressive pricing pursue', 'restrictive distribution agreements', 'supply direct consumers', 'potential customers restrictive', 'devote resources', 'technology infrastructure fulfillment', 'facilitates competitive entry', 'enhances ability', 'development business models', 'business combinations alliances strengthen', 'service marks', 'domain names', 'trade dress trade secrets proprietary', 'rely', 'law', 'confidentiality license', 'employees customers partners', 'international domain names', 'applications covering', 'business affected seasonality', 'sales volume', 'results revenue', 'employment levels fluctuate', 'seasonal factors affecting', 'contractors temporary personnel', 'works councils statutory', 'employee representation obligations', 'union agreements', 'Competition qualified personnel', 'software engineers scientists', 'investor relations website', 'website free charge', 'corporate governance information', 'select press releases', 'Executive Officers Directors', 'tables set', 'information', 'numerous financial leadership roles']

# %% [markdown]
# ### Only keep Trigrams & Quadgrams

# %%
#4. Only keeping bigrams, trigrams, quadgrams
final_phrases = candidate_generation.get_ngrams(phrases_wo_nonenglish_words, (3,4))
print(final_phrases)
# Out:
# ['expressed forward-looking statements', 'principal corporate offices located', 'common stock listed', 'competitor focus passion invention', 'customer sets consisting', 'consumers sellers developers', 'sellers vendors publishers', 'sponsored ads display', 'business performance manages', 'net sales contained', 'results Whole Foods', 'online physical stores', 'focus selection price', 'hundreds millions unique', 'websites mobile apps', 'sell electronic devices', 'produce media content', 'customers low prices', 'delivery easy-to-use functionality', 'unlimited free shipping', 'unlimited streaming tens', 'movies TV episodes', 'fulfill customer orders', 'fulfillment delivery networks', 'operate customer service centers', 'supplemented co-sourced arrangements', 'percentage sales per-unit', 'serve developers enterprises', 'set global compute', 'authors independent publishers', 'authors publishers choose', 'filmmakers skill app developers', 'large variety product types', 'retailers publishers vendors', 'networks web portals', 'acquiring goods services', 'fulfillment logistics services', 'information technology services products', 'on-premises cloud-based infrastructure', 'design manufacture market', 'sell consumer electronics telecommunication', 'grocery products online', 'fast reliable fulfillment', 'seller enterprise services', 'change business practices', 'resources longer histories', 'customers greater brand recognition', 'control inputs critical', 'terms suppliers adopt', 'aggressive pricing pursue', 'restrictive distribution agreements', 'supply direct consumers', 'potential customers restrictive', 'technology infrastructure fulfillment', 'facilitates competitive entry', 'development business models', 'business combinations alliances strengthen', 'employees customers partners', 'international domain names', 'business affected seasonality', 'employment levels fluctuate', 'seasonal factors affecting', 'contractors temporary personnel', 'works councils statutory', 'employee representation obligations', 'Competition qualified personnel', 'software engineers scientists', 'investor relations website', 'website free charge', 'corporate governance information', 'select press releases', 'Executive Officers Directors', 'numerous financial leadership roles']

# %% [markdown]
# ## Step 5: TextRank

# %% [markdown]
# ### Score based on Word Embeddings Method

# %%
TR_WordEmbedding= TextRank(description, method= "WordEmbeddings")
WE_Phrases = TR_WordEmbedding.rank_phrases(final_phrases)

# %%
display(WE_Phrases)
# Out:
#                                         Phrases     Score
# 0      information technology services products  0.017447
# 1              operate customer service centers  0.016707
# 2                     change business practices  0.016691
# 3                       supply direct consumers  0.016655
# 4                   large variety product types  0.016563
# 5                   development business models  0.016344
# 6               potential customers restrictive  0.016341
# 7           customers greater brand recognition  0.016308
# 8                    seller enterprise services  0.016046
# 9                         produce media content  0.015837
# 10             corporate governance information  0.015796
# 11                        terms suppliers adopt  0.015776
# 12                       online physical stores  0.015772
# 13                     acquiring goods services  0.015617
# 14                 employees customers partners  0.015603
# 15                      grocery products online  0.015576
# 16                 business performance manages  0.015544
# 17                         customers low prices  0.015457
# 18                        focus selection price  0.015436
# 19                    design manufacture market  0.015195
# 20        technology infrastructure fulfillment  0.015031
# 21                 serve developers enterprises  0.014953
# 22                      sell electronic devices  0.014900
# 23                          website free charge  0.014897
# 24                   resources longer histories  0.014883
# 25   business combinations alliances strengthen  0.014750
# 26  sell consumer electronics telecommunication  0.014716
# 27                 consumers sellers developers  0.014689
# 28                     customer sets consisting  0.014617
# 29          numerous financial leadership roles  0.014454
# 30                           set global compute  0.014435
# 31                          net sales contained  0.014428
# 32                business affected seasonality  0.014311
# 33                      fulfill customer orders  0.014300
# 34                     hundreds millions unique  0.014220
# 35          principal corporate offices located  0.014020
# 36                fulfillment delivery networks  0.013987
# 37                          common stock listed  0.013881
# 38          restrictive distribution agreements  0.013858
# 39                      unlimited free shipping  0.013830
# 40                      control inputs critical  0.013781
# 41                    aggressive pricing pursue  0.013654
# 42                         networks web portals  0.013610
# 43               fulfillment logistics services  0.013567
# 44                   international domain names  0.013549
# 45                   investor relations website  0.013477
# 46                facilitates competitive entry  0.013424
# 47                 retailers publishers vendors  0.013401
# 48                    fast reliable fulfillment  0.013254
# 49                    authors publishers choose  0.013227
# 50              filmmakers skill app developers  0.013211
# 51                        select press releases  0.013192
# 52          employee representation obligations  0.013070
# 53                software engineers scientists  0.013021
# 54               authors independent publishers  0.012869
# 55           competitor focus passion invention  0.012775
# 56                   sellers vendors publishers  0.012675
# 57                        sponsored ads display  0.012600
# 58              contractors temporary personnel  0.012507
# 59                  employment levels fluctuate  0.012066
# 60                   seasonal factors affecting  0.012017
# 61                         websites mobile apps  0.011944
# 62                    percentage sales per-unit  0.011618
# 63                     works councils statutory  0.011459
# 64                     unlimited streaming tens  0.011182
# 65              Competition qualified personnel  0.010995
# 66                          results Whole Foods  0.010469
# 67         supplemented co-sourced arrangements  0.010251
# 68           delivery easy-to-use functionality  0.009526
# 69         expressed forward-looking statements  0.009244
# 70                           movies TV episodes  0.008807
# 71       on-premises cloud-based infrastructure  0.007609
# 72                 Executive Officers Directors  0.002079

# %% [markdown]
# ### Score based on Window Size Method

# %%
TR_WindowSize = TextRank(original_text = description, method= "WindowSize")
WS_Phrases = TR_WindowSize.rank_phrases(final_phrases)

# %%
display(WS_Phrases)
# Out:
#                                 Phrases     Score
# 0      operate customer service centers  0.067889
# 1                  customers low prices  0.051408
# 2               fulfill customer orders  0.050850
# 3             change business practices  0.050236
# 4               sell electronic devices  0.047606
# 5                 produce media content  0.040315
# 6   restrictive distribution agreements  0.039685
# 7   numerous financial leadership roles  0.038699
# 8      corporate governance information  0.036529
# 9            international domain names  0.035637
# 10              unlimited free shipping  0.033299
# 11                select press releases  0.033194
# 12        facilitates competitive entry  0.031624
# 13           investor relations website  0.030654
# 14  employee representation obligations  0.030172
# 15           seasonal factors affecting  0.029531
# 16              grocery products online  0.024561
# 17          employment levels fluctuate  0.015894
